# %% [markdown]
# # Persistance Homology
#
# This follows `\notes\tda.tex`, note that

# %%
import numpy as np
import gudhi as gd
import matplotlib.pyplot as plt

import sys
sys.path.append("..")

from src.utils.tda import *
from src.utils.autocorrelation import autocorrelation
from src.utils.msep import MultiSpeciesExclusionProcess
from src.utils.relaxation_time import relaxation_time

# %%
points = np.array([[0.8, 4.9], [1.2, 3.6], [1.6, 2.5], [1.4, 1.6], [1.8, 5.7], [2.7, 4.9], [3.2, 0.8], [3.9, 6.1], [2.2, 3.8], [5.7, 5.6], [7.0, 5.2], [8.2, 4.9], [8.0, 3.7], [7.0, 2.6], [8.4, 2.5], [6.8, 1.1], [8.2, 1.4], [5.5, 0.4]])

plt.figure(figsize=(9, 6), dpi=300)

plt.scatter(points[:, 0], points[:, 1])
plt.title("2d point cloud")
plt.axis("equal")
plt.show()

# %%
points = np.array([[0.8, 4.9], [1.2, 3.6], [1.6, 2.5], [1.4, 1.6], [1.8, 5.7], [2.7, 4.9], [3.2, 0.8], [3.9, 6.1], [2.2, 3.8], [5.7, 5.6], [7.0, 5.2], [8.2, 4.9], [8.0, 3.7], [7.0, 2.6], [8.4, 2.5], [6.8, 1.1], [8.2, 1.4], [5.5, 0.4]])

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10), dpi=300)

diameters = [1, 2, 3, 4]

for ax, d in zip(axes.flatten(), diameters):
    draw_rips_simplices(points=points, axes=ax, d=d)

plt.tight_layout()
plt.show()
